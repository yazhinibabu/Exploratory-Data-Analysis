# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Use pandas to read the dataset and check the first few rows to understand its structure.
df=pd.read_csv('Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.size
# Out:
# 29764

# %%
df.info
# Out:
# <bound method DataFrame.info of               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
meanlb=df['LB'].mean()
meanlb
# Out:
# 133.3435983550352

# %%
meanac=df['AC'].mean()
meanac
# Out:
# 0.0032189782438000465

# %%
mediands=df['DS'].median()
mediands
# Out:
# 0.0

# %%
mediandp=df['DP'].median()
mediandp
# Out:
# 0.0

# %%
medianmltv=df['MLTV'].median()
medianmltv
# Out:
# 7.4

# %%
medianwidth=df['Width'].median()
medianwidth
# Out:
# 67.0

# %%
meantendency=df['Tendency'].mean()
meantendency
# Out:
# 0.3163714038702473

# %%
meannsp=df['NSP'].mean()
meannsp
# Out:
# 1.304507175110962

# %%
# Fill the missing values with the column mean or median respectively
df.fillna({'LB':meanlb,'AC':meanac,'DS':mediands,'DP':mediandp,'MLTV':medianmltv,'Width':medianwidth,'Tendency':meantendency,'NSP':meannsp},inplace=True)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Check to make sure there are no more missing values
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
#Check for duplicate values
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2126, dtype: bool

# %%
#Identify the duplicate rows
df[df.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
# Drop the duplicate rows
df.drop_duplicates(keep='first',inplace=True,ignore_index=True)
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2119  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2120  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2121  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2123  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Define function for detecting outliers using IQR for all the numerical columns
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Apply outlier removal to all numerical columns
def remove_outliers_all(df):
    for column in df.select_dtypes(include=['float64', 'int64']).columns:
        df = remove_outliers(df, column)
    return df

# Apply the function to the entire dataframe
df_cleaned = remove_outliers_all(df)
df=df_cleaned

# Display the cleaned dataframe
df
# Out:
#          LB        AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# 1     132.0  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 2     133.0  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 58    148.0  0.000000  0.000000  0.005181  0.000000  0.0  0.0  41.0   0.8
# 59    144.0  0.008143  0.000000  0.006595  0.000000  0.0  0.0  33.0   1.1
# 61    146.0  0.004580 -0.001776  0.004580  0.000000  0.0  0.0  39.0   0.8
# ...     ...       ...       ...       ...       ...  ...  ...   ...   ...
# 2115  140.0  0.000000  0.000000  0.007812  0.000000  0.0  0.0  79.0   0.3
# 2116  140.0  0.000000  0.000000  0.006470  0.000898  0.0  0.0  79.0   0.5
# 2117  140.0  0.000000  0.000000  0.006764  0.001127  0.0  0.0  79.0   0.6
# 2118  140.0  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0   0.7
# 2123  142.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency  NSP
# ...

# %%
# Get statistical summary
summary_stats = df.describe()

# Display summary statistics
summary_stats
# Out:
#                LB          AC          FM          UC          DL     DS  \
# count  903.000000  903.000000  903.000000  903.000000  903.000000  903.0
# mean   132.187651    0.003900    0.000593    0.004898    0.001540    0.0
# std      9.367814    0.003727    0.001311    0.002684    0.002278    0.0
# min    106.000000   -0.000122   -0.002076   -0.000101   -0.000124    0.0
# 25%    125.000000    0.000000    0.000000    0.003122    0.000000    0.0
# 50%    133.000000    0.003052    0.000000    0.004985    0.000000    0.0
# 75%    139.000000    0.006569    0.000296    0.006834    0.002768    0.0
# max    160.000000    0.013861    0.006272    0.012072    0.008464    0.0
#
#           DP        ASTV        MSTV        ALTV        MLTV       Width  \
# count  903.0  903.000000  903.000000  903.000000  903.000000  903.000000
# mean     0.0   42.958287    1.222243    4.407774    8.422932   65.831832
# std      0.0   15.168783    0.501376    8.320266    4.351327   31.409482
# ...

# %%
numerical_columns = df.select_dtypes(include=['number']).columns.tolist()
numerical_columns
# Out:
# ['LB',
#  'AC',
#  'FM',
#  'UC',
#  'DL',
#  'DS',
#  'DP',
#  'ASTV',
#  'MSTV',
#  'ALTV',
#  'MLTV',
#  'Width',
#  'Tendency',
#  'NSP']

# %%
#Plot histograms for the numerical columns
numerical_columns = ['LB','AC','FM','UC','DL','DS','DP','ASTV','MSTV','ALTV','MLTV','Width','Tendency','NSP']
plt.figure(figsize=(15, 20))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(7, 2, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
numerical_columns = ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'Tendency', 'NSP']
plt.figure(figsize=(15, 20))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(7, 2, i)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
plt.tight_layout()
plt.show()

# %%
# Check for specific correlations
correlations = df.corr()
correlations
# Out:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000  0.057708 -0.008220 -0.010417  0.030619 NaN NaN  0.282578
# AC        0.057708  1.000000  0.086565  0.061372 -0.105547 NaN NaN -0.005684
# FM       -0.008220  0.086565  1.000000 -0.216980  0.070780 NaN NaN  0.359485
# UC       -0.010417  0.061372 -0.216980  1.000000  0.170312 NaN NaN -0.006069
# DL        0.030619 -0.105547  0.070780  0.170312  1.000000 NaN NaN -0.004214
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.282578 -0.005684  0.359485 -0.006069 -0.004214 NaN NaN  1.000000
# MSTV     -0.248125  0.191780  0.107744  0.075072  0.513642 NaN NaN -0.398593
# ALTV      0.157112 -0.349982 -0.092224 -0.070964 -0.123558 NaN NaN  0.199288
# MLTV     -0.130117 -0.384486 -0.099630 -0.112184 -0.236327 NaN NaN -0.323652
# ...

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Pairplot for selected columns
sns.pairplot(df[['LB', 'AC', 'FM', 'UC']])
plt.show()
